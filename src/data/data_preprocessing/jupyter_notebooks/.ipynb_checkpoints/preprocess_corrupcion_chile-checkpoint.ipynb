# %%
import pandas as pd

# %%
pd.read_excel(io = './../original_data/corrupcion_chile_bastian_olea/casos_corrupcion_chile.xlsx')
# Out:
#                                                  Caso         Monto   Año  \
# 0       Alcaldesa de Viña del Mar (Virginia Reginato)  1.000000e+11  2021
# 1                     Fraude en Carabineros, Pacogate  3.500000e+10  2016
# 2                  Alcaldesa de Maipú (Cathy Barriga)  3.100000e+10  2024
# 3                                          Caso Penta  3.010000e+10  2014
# 4                               Caso Riggs (Pinochet)  2.680000e+10  2014
# ..                                                ...           ...   ...
# 82           Director general de PDI, Héctor Espinosa  1.460000e+08  2021
# 83  Caso Luminarias: concejal de Iquique (Felipe A...  5.000000e+08  2024
# 84  Caso Cuentas Corrientes, alcalde de San Ignaci...           NaN  2023
# 85  Caso Cuentas Corrientes, alcalde de Ñiquén (Ma...           NaN  2023
# 86  Caso Cuentas Corrientes, alcalde de Bulnes, (G...           NaN  2023
#
#                                           Responsable   Sector Partido  \
# ...
